# %%
#Activity Log
**Bolortulga Seded**
**11 February 2026**
**Week 1**
**Tasks:** shape, head(), tail(), info(), describe()

# %%
import pandas as pd
excel_file = 'movies.xls'
movies = pd.read_excel(excel_file)

# %%
print(movies.shape)
# Out:
# (1338, 25)

# %%
movies.tail()
# Out:
#                                Title  Year                        Genres  \
# 1333               Twin Falls Idaho   1999                         Drama
# 1334  Universal Soldier: The Return   1999                 Action|Sci-Fi
# 1335                  Varsity Blues   1999    Comedy|Drama|Romance|Sport
# 1336                 Wild Wild West   1999  Action|Comedy|Sci-Fi|Western
# 1337                 Wing Commander   1999       Action|Adventure|Sci-Fi
#
#      Language Country Content Rating  Duration  Aspect Ratio       Budget  \
# 1333  English     USA              R       111          1.85     500000.0
# 1334  English     USA              R        83          1.85   24000000.0
# 1335  English     USA              R       106          1.85   16000000.0
# 1336  English     USA          PG-13       106          1.85  170000000.0
# 1337  English     USA          PG-13       100          2.35   30000000.0
#
#       Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# ...

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        1338 non-null   str
#  1   Year                         1338 non-null   int64
#  2   Genres                       1338 non-null   str
#  3   Language                     1333 non-null   str
#  4   Country                      1338 non-null   str
#  5   Content Rating               1316 non-null   str
#  6   Duration                     1338 non-null   int64
#  7   Aspect Ratio                 1308 non-null   float64
#  8   Budget                       1281 non-null   float64
#  9   Gross Earnings               1086 non-null   float64
#  10  Director                     1338 non-null   str
#  11  Actor 1                      1338 non-null   str
#  12  Actor 2                      1338 non-null   str
# ...

# %%
movies.describe()
# Out:
#               Year     Duration  Aspect Ratio        Budget  Gross Earnings  \
# count  1338.000000  1338.000000   1308.000000  1.281000e+03    1.086000e+03
# mean   1987.289985   113.071001      1.987752  2.712064e+07    4.752741e+07
# std      14.124870    27.434048      0.310047  8.466937e+07    6.113161e+07
# min    1916.000000    25.000000      1.180000  7.000000e+03    5.494000e+03
# 25%    1982.000000    96.000000      1.850000  4.000000e+06    8.182800e+06
# 50%    1993.000000   107.000000      1.850000  1.400000e+07    2.724075e+07
# 75%    1997.000000   123.000000      2.350000  3.300000e+07    6.358500e+07
# max    1999.000000   330.000000      2.760000  2.400000e+09    6.586723e+08
#
#        Facebook Likes - Director  Facebook Likes - Actor 1  \
# count                1338.000000               1338.000000
# mean                 1026.567265               5255.186846
# std                  3446.329257               8652.096738
# ...
